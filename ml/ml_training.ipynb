# %% [markdown]
# # ML – PyCaret demo (opcjonalne)
# Krótki przykład trenowania modelu PyCaret dla problemu regresji.

# %%
from pycaret.regression import setup, compare_models
import pandas as pd
df = pd.read_csv('../data/avocado.csv')
exp = setup(df, target='AveragePrice', session_id=42, silent=True, verbose=False)
best = compare_models()
